# %%
news1 = "Próximo adversário do Atlético na Série A do Campeonato Brasileiro, o Corinthians volta a campo nesta quinta-feira (25), às 20h (horário de Brasília), pela 19ª rodada da competição nacional, contra o Grêmio. Para a partida na Neo Química Arena, o Timão tem sete jogadores pendurados, ou seja, que podem não enfrentar o Galo."

# %%
news2 = "Embalado por duas vitórias seguidas, o Corinthians entra em campo buscando ampliar a vantagem de pontos para a zona de rebaixamento e encerrar o primeiro turno de maneira positiva. Para isso, o Timão deve receber o apoio de mais de 40 mil pessoas e aproveitar o bom momento sob comando do técnico argentino Ramón Díaz."

# %%
# NOTICIA 1
# Próximo adversário do Atlético na Série A do Campeonato Brasileiro, o Corinthians volta a campo nesta quinta-feira (25), às 20h (horário de Brasília), pela 19ª rodada da competição nacional, contra o Grêmio. Para a partida na Neo Química Arena, o Timão tem sete jogadores pendurados, ou seja, que podem não enfrentar o Galo.

# %%
# NOTICIA 2
# Embalado por duas vitórias seguidas, o Corinthians entra em campo buscando ampliar a vantagem de pontos para a zona de rebaixamento e encerrar o primeiro turno de maneira positiva. Para isso, o Timão deve receber o apoio de mais de 40 mil pessoas e aproveitar o bom momento sob comando do técnico argentino Ramón Díaz.

# %%
from sklearn.feature_extraction.text import CountVectorizer
doc = [str(news1)]
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(doc)

# %%
corpus = vectorizer.get_feature_names_out()

# %%
corpus
# Out:
# array(['19ª', '20h', '25', 'adversário', 'arena', 'atlético',
#        'brasileiro', 'brasília', 'campeonato', 'campo', 'competição',
#        'contra', 'corinthians', 'da', 'de', 'do', 'enfrentar', 'feira',
#        'galo', 'grêmio', 'horário', 'jogadores', 'na', 'nacional', 'neo',
#        'nesta', 'não', 'ou', 'para', 'partida', 'pela', 'pendurados',
#        'podem', 'próximo', 'que', 'quinta', 'química', 'rodada', 'seja',
#        'sete', 'série', 'tem', 'timão', 'volta', 'às'], dtype=object)

# %%
consulta = 'Qual é a atual situação do timão, Corinthians na tabela de classificação do campeonato após duas vitórias seguidas e qual a expectativa para o jogo com o apoio de mais de 40 mil torcedores do timão?'

# %%
docConsu = [str(consulta)]
vectorizer2 = CountVectorizer()
C = vectorizer2.fit_transform(docConsu)

# %%
consul = vectorizer2.get_feature_names_out()
consul
# Out:
# array(['40', 'apoio', 'após', 'atual', 'campeonato', 'classificação',
#        'com', 'corinthians', 'de', 'do', 'duas', 'expectativa', 'jogo',
#        'mais', 'mil', 'na', 'para', 'qual', 'seguidas', 'situação',
#        'tabela', 'timão', 'torcedores', 'vitórias'], dtype=object)

# %%
from collections import Counter
cont = Counter(corpus)
cont
# Out:
# Counter({'19ª': 1,
#          '20h': 1,
#          '25': 1,
#          'adversário': 1,
#          'arena': 1,
#          'atlético': 1,
#          'brasileiro': 1,
#          'brasília': 1,
#          'campeonato': 1,
#          'campo': 1,
#          'competição': 1,
#          'contra': 1,
#          'corinthians': 1,
#          'da': 1,
#          'de': 1,
#          'do': 1,
#          'enfrentar': 1,
#          'feira': 1,
#          'galo': 1,
#          'grêmio': 1,
#          'horário': 1,
#          'jogadores': 1,
#          'na': 1,
#          'nacional': 1,
#          'neo': 1,
#          'nesta': 1,
#          'não': 1,
#          'ou': 1,
#          'para': 1,
#          'partida': 1,
#          'pela': 1,
#          'pendurados': 1,
#          'podem': 1,
#          'próximo': 1,
#          'que': 1,
#          'quinta': 1,
#          'química': 1,
#          'rodada': 1,
#          'seja': 1,
#          'sete': 1,
#          'série': 1,
#          'tem': 1,
#          'timão': 1,
#          'volta': 1,
#          'às': 1})

# %%
contConsu = Counter(consul)
contConsu
# Out:
# Counter({'40': 1,
#          'apoio': 1,
#          'após': 1,
#          'atual': 1,
#          'campeonato': 1,
#          'classificação': 1,
#          'com': 1,
#          'corinthians': 1,
#          'de': 1,
#          'do': 1,
#          'duas': 1,
#          'expectativa': 1,
#          'jogo': 1,
#          'mais': 1,
#          'mil': 1,
#          'na': 1,
#          'para': 1,
#          'qual': 1,
#          'seguidas': 1,
#          'situação': 1,
#          'tabela': 1,
#          'timão': 1,
#          'torcedores': 1,
#          'vitórias': 1})

# %%
freq = []

for i in consul:
     for b in cont:
        if i == b:
            freq.append(i)

# %%
cont = Counter(freq)
cont
# Out:
# Counter({'campeonato': 1,
#          'corinthians': 1,
#          'de': 1,
#          'do': 1,
#          'na': 1,
#          'para': 1,
#          'timão': 1})

# %%
frequen = 0
for n in freq:
    frequen += 1

# %%
contagem = 0
for n in corpus:
    contagem += 1

# %%
import math
normaFreq = (frequen / contagem) * 100
score = math.log(normaFreq)

# %%
from math import log10
from sklearn.feature_extraction.text import CountVectorizer
corpus = vectorizer.get_feature_names_out()



class TextCleaner(object):


    def __init__(self, doc):
        self.doc = [str(doc)]


    def process(self):
        """
        Remove the Stop words
        :return: List []
        """
        vectorizer = CountVectorizer()
        X = vectorizer.fit_transform(self.doc)
        corpus = vectorizer.get_feature_names_out()
        return corpus
    
class WordFrequency(object):


    def __init__(self, data):
        self.data = data


    def process(self):
        """
        Gets the Frequency Count
        :return: Json
        """
        data = Counter(self.data)
        return data
    
def main(json,query):
    helper = TextCleaner(doc=json)
    corpus = helper.process()           # get the Bags of Words


    helper = WordFrequency(data=corpus)
    corpus_freq = helper.process()      # get the Json of Words freq


    # Step 2:
    helper = TextCleaner(doc=query)
    vocubulary = helper.process()         # get the Bags of Words


    freq = []
    for i in vocubulary:
        try:
            tem = corpus_freq[i]
            freq.append(tem)
        except Exception:
            pass


    score  = sum(freq) /len(corpus)
    score = log10(len(corpus))
    return score

# %%
freq
# Out:
# ['campeonato', 'corinthians', 'de', 'do', 'na', 'para', 'timão']

# %%
#News 1
query = 'Qual é a atual situação do timão, Corinthians na tabela de classificação do campeonato após duas vitórias seguidas e qual a expectativa para o jogo com o apoio de mais de 40 mil torcedores do timão?'
score = main(json=news1, query=query)
print("Score: {} ".format(score))
# Out:
# Score: 1.6532125137753437

# %%
#News 2
query = 'Qual é a atual situação do timão, Corinthians na tabela de classificação do campeonato após duas vitórias seguidas e qual a expectativa para o jogo com o apoio de mais de 40 mil torcedores do timão?'
score = main(json=news2, query=query)
print("Score: {} ".format(score))
# Out:
# Score: 1.6127838567197355
